# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/Users/noa/Desktop/M2/S1/SVM/SVM/data/high_popularity_spotify_data.csv')

# %%
df.head()
# Out:
#    energy    tempo  danceability playlist_genre  loudness  liveness  valence  \
# 0   0.592  157.969         0.521            pop    -7.777     0.122    0.535
# 1   0.507  104.978         0.747            pop   -10.171     0.117    0.438
# 2   0.808  108.548         0.554            pop    -4.169     0.159    0.372
# 3   0.910  112.966         0.670            pop    -4.070     0.304    0.786
# 4   0.783  149.027         0.777            pop    -4.477     0.355    0.939
#
#             track_artist  time_signature  speechiness  ...  instrumentalness  \
# 0  Lady Gaga, Bruno Mars               3       0.0304  ...            0.0000
# 1          Billie Eilish               4       0.0358  ...            0.0608
# 2          Gracie Abrams               4       0.0368  ...            0.0000
# 3      Sabrina Carpenter               4       0.0634  ...            0.0000
# 4       ROSÉ, Bruno Mars               4       0.2600  ...            0.0000
#
#            track_album_id mode key duration_ms acousticness  \
# 0  10FLjwfpbxLmW8c25Xyc2N    0   6      251668       0.3080
# 1  7aJuG4TFXa2hmE4z1yxc3n    1   2      210373       0.2000
# 2  0hBRqPYPXhr1RkTDG3n4Mk    1   1      166300       0.2140
# 3  4B4Elma4nNDUyl6D5PvQkj    0   0      157280       0.0939
# 4  2IYQwwgxgOIn7t3iF6ufFD    0   0      169917       0.0283
#
#                        id playlist_subgenre            type  \
# 0  2plbrEY59IikOBgBGLjaoe        mainstream  audio_features
# 1  6dOtVTDdiauQNBQEDOtlAB        mainstream  audio_features
# 2  7ne4VBA60CxGM75vw0EYad        mainstream  audio_features
# 3  1d7Ptw3qYcfpdLNL5REhtJ        mainstream  audio_features
# 4  5vNRhkKd0yEAg8suGBpjeY        mainstream  audio_features
#
#               playlist_id
# 0  37i9dQZF1DXcBWIGoYBM5M
# 1  37i9dQZF1DXcBWIGoYBM5M
# 2  37i9dQZF1DXcBWIGoYBM5M
# 3  37i9dQZF1DXcBWIGoYBM5M
# 4  37i9dQZF1DXcBWIGoYBM5M
#
# [5 rows x 29 columns]

# %%
df.dtypes
# Out:
# energy                      float64
# tempo                       float64
# danceability                float64
# playlist_genre               object
# loudness                    float64
# liveness                    float64
# valence                     float64
# track_artist                 object
# time_signature                int64
# speechiness                 float64
# track_popularity              int64
# track_href                   object
# uri                          object
# track_album_name             object
# playlist_name                object
# analysis_url                 object
# track_id                     object
# track_name                   object
# track_album_release_date     object
# instrumentalness            float64
# track_album_id               object
# mode                          int64
# key                           int64
# duration_ms                   int64
# acousticness                float64
# id                           object
# playlist_subgenre            object
# type                         object
# playlist_id                  object
# dtype: object

# %%
df.describe()
# Out:
#             energy        tempo  danceability     loudness     liveness  \
# count  1686.000000  1686.000000   1686.000000  1686.000000  1686.000000
# mean      0.667216   121.070938      0.650362    -6.704131     0.171579
# std       0.184908    27.066029      0.157721     3.377068     0.123953
# min       0.001610    49.305000      0.136000   -43.643000     0.021000
# 25%       0.551000   100.058750      0.543250    -7.950250     0.093400
# 50%       0.689000   120.001000      0.664500    -5.974500     0.121000
# 75%       0.807000   136.833500      0.769000    -4.687250     0.210000
# max       0.990000   209.688000      0.979000     1.295000     0.950000
#
#            valence  time_signature  speechiness  track_popularity  \
# count  1686.000000     1686.000000  1686.000000       1686.000000
# mean      0.525737        3.950178     0.100926         75.806050
# std       0.236113        0.326673     0.099748          6.032532
# min       0.034800        1.000000     0.023200         68.000000
# 25%       0.339000        4.000000     0.037900         71.000000
# 50%       0.528000        4.000000     0.058100         75.000000
# 75%       0.720000        4.000000     0.118000         79.000000
# max       0.978000        5.000000     0.848000        100.000000
#
#        instrumentalness         mode          key    duration_ms  acousticness
# count       1686.000000  1686.000000  1686.000000    1686.000000   1686.000000
# mean           0.041520     0.578292     5.338078  214562.125741      0.221220
# std            0.156556     0.493979     3.608208   58310.747929      0.250593
# min            0.000000     0.000000     0.000000   61673.000000      0.000013
# 25%            0.000000     0.000000     2.000000  176607.750000      0.023050
# 50%            0.000006     1.000000     5.000000  211180.000000      0.124000
# 75%            0.000814     1.000000     8.000000  244993.250000      0.334750
# max            0.971000     1.000000    11.000000  547107.000000      0.995000

# %%
# Somme des NA
df.isnull().sum()
# Out:
# energy                      0
# tempo                       0
# danceability                0
# playlist_genre              0
# loudness                    0
# liveness                    0
# valence                     0
# track_artist                0
# time_signature              0
# speechiness                 0
# track_popularity            0
# track_href                  0
# uri                         0
# track_album_name            1
# playlist_name               0
# analysis_url                0
# track_id                    0
# track_name                  0
# track_album_release_date    0
# instrumentalness            0
# track_album_id              0
# mode                        0
# key                         0
# duration_ms                 0
# acousticness                0
# id                          0
# playlist_subgenre           0
# type                        0
# playlist_id                 0
# dtype: int64

# %%
corr = df.corr(method='spearman')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e4fbd_row0_col0, #T_e4fbd_row1_col1, #T_e4fbd_row2_col2, #T_e4fbd_row3_col3, #T_e4fbd_row4_col4, #T_e4fbd_row5_col5, #T_e4fbd_row6_col6, #T_e4fbd_row7_col7, #T_e4fbd_row8_col8, #T_e4fbd_row9_col9, #T_e4fbd_row10_col10, #T_e4fbd_row11_col11, #T_e4fbd_row12_col12, #T_e4fbd_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e4fbd_row0_col1, #T_e4fbd_row3_col2, #T_e4fbd_row12_col9 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e4fbd_row0_col2, #T_e4fbd_row0_col11, #T_e4fbd_row1_col6, #T_e4fbd_row9_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e4fbd_row0_col3 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_e4fbd_row0_col4, #T_e4fbd_row11_col9 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e4fbd_row0_col5, #T_e4fbd_row4_col3, #T_e4fbd_row8_col0, #T_e4fbd_row9_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e4fbd_row0_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_e4fbd_row0_col7, #T_e4fbd_row3_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e4fbd_row0_col8, #T_e4fbd_row2_col11, #T_e4fbd_row4_col6, #T_e4fbd_row5_col12 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e4fbd_row4_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_e4fbd_row4_col12, #T_e4fbd_row7_col4, #T_e4fbd_row8_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e4fbd_row4_col13 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_e4fbd_row5_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_e4fbd_row5_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_e4fbd_row5_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_e4fbd_row5_col4, #T_e4fbd_row8_col7, #T_e4fbd_row9_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e4fbd_row5_col6, #T_e4fbd_row6_col13, #T_e4fbd_row9_col12 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e4fbd_row5_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e4fbd_row5_col10, #T_e4fbd_row8_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e4fbd_row6_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e4fbd_row6_col3, #T_e4fbd_row8_col13 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_e4fbd_row6_col4, #T_e4fbd_row11_col4, #T_e4fbd_row12_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_e4fbd_row6_col5, #T_e4fbd_row11_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e4fbd_row6_col7, #T_e4fbd_row10_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e4fbd_row6_col9, #T_e4fbd_row10_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e4fbd_row7_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_e4fbd_row7_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e4fbd_row7_col3, #T_e4fbd_row10_col13, #T_e4fbd_row11_col13 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e4fbd_row7_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_e4fbd_row7_col8, #T_e4fbd_row7_col10, #T_e4fbd_row13_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e4fbd_row7_col12 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e4fbd_row7_col13 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_e4fbd_row8_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_e4fbd_row8_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_e4fbd_row8_col5, #T_e4fbd_row10_col7, #T_e4fbd_row11_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e4fbd_row8_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e4fbd_row8_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e4fbd_row9_col3, #T_e4fbd_row10_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e4fbd_row9_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e4fbd_row9_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e4fbd_row10_col2, #T_e4fbd_row10_col4, #T_e4fbd_row13_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e4fbd_row10_col8, #T_e4fbd_row13_col10, #T_e4fbd_row13_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e4fbd_row10_col9, #T_e4fbd_row11_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e4fbd_row11_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e4fbd_row11_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e4fbd_row11_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e4fbd_row12_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_e4fbd_row13_c

# %%
# Transformer les variables object en catégories
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].astype('category')

# %%
df.dtypes
# Out:
# energy                       float64
# tempo                        float64
# danceability                 float64
# playlist_genre              category
# loudness                     float64
# liveness                     float64
# valence                      float64
# track_artist                category
# time_signature                 int64
# speechiness                  float64
# track_popularity               int64
# track_href                  category
# uri                         category
# track_album_name            category
# playlist_name               category
# analysis_url                category
# track_id                    category
# track_name                  category
# track_album_release_date    category
# instrumentalness             float64
# track_album_id              category
# mode                           int64
# key                            int64
# duration_ms                    int64
# acousticness                 float64
# id                          category
# playlist_subgenre           category
# type                        category
# playlist_id                 category
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, :4],  
                                                    df['track_popularity'], 
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=42)

# %%
y_train.value_counts()
# Out:
# 73     108
# 70     107
# 68      97
# 71      94
# 72      93
# 75      90
# 69      82
# 77      81
# 74      75
# 78      71
# 76      71
# 79      50
# 81      47
# 84      43
# 80      40
# 83      36
# 82      34
# 88      24
# 85      22
# 86      19
# 89      18
# 87      12
# 93      11
# 90       8
# 92       5
# 97       3
# 94       3
# 100      3
# 98       1
# Name: track_popularity, dtype: int64
